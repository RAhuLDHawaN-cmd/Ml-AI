# %%
# Out:
# [[0.82027938]
#  [0.97438708]
#  [0.11202629]
#  [0.37646924]
#  [0.55391159]
#  [0.41293132]
#  [0.49300659]
#  [0.96275433]
#  [0.08786818]
#  [0.34947497]]
# 0.514310898023387

# %%
array1=np.random.random(size=(20,1))
print(array1)
var=array1.var()
std=array1.std()
print(var)
print(std)
# Out:
# [[0.97598496]
#  [0.54964138]
#  [0.29549956]
#  [0.64779528]
#  [0.34629607]
#  [0.03368468]
#  [0.3482323 ]
#  [0.09342823]
#  [0.7027601 ]
#  [0.813954  ]
#  [0.0165539 ]
#  [0.2146278 ]
#  [0.24878988]
#  [0.97217659]
#  [0.59346358]
#  [0.28133543]
#  [0.13118434]
#  [0.51341232]
#  [0.97259057]
#  [0.27721247]]
# 0.09407721065566757
# 0.30672008518463145

# %%
arr=np.random.random(size=(10,20))
arr1=np.random.random(size=(20,25))
arr2=np.matmul(arr,arr1)
print(arr2)
arr2.sum()
# Out:
# [[4.93184185 4.52457008 4.54477739 4.60398764 4.8707801  3.75936873
#   4.00277789 4.71592854 4.63227115 4.04784757 3.79969031 4.21170776
#   4.40989102 3.96332953 4.78330812 3.27546283 4.27120763 4.38065953
#   3.48880366 4.50033305 4.30154454 4.811724   3.85959704 4.76919417
#   4.97919249]
#  [4.98767852 4.72132692 5.34255611 6.58598773 6.25451512 5.60349833
#   5.29947136 4.75251462 5.41537051 4.62900678 5.06077371 5.44047212
#   5.03137269 4.80902938 4.69467178 4.20863458 4.97867929 4.97167283
#   4.13769617 4.79323439 4.66770549 5.25656755 4.77481163 5.12969249
#   4.5037608 ]
#  [4.64535923 4.32142793 4.87559716 4.42448857 4.30656191 3.19573776
#   4.17681913 3.72539254 3.86092622 3.64252635 3.57932626 3.52084541
#   4.59640583 3.7026298  3.70846842 3.77428378 4.53672534 3.56515173
#   3.35060602 3.16142833 3.62712409 3.54828223 3.00632997 3.7921396
#   4.26228485]
#  [5.24085305 5.30504022 5.65300351 5.90218496 5.49036967 5.43433271
#   4.46114314 4.42614919 4.77238578 4.68561074 5.62919695 4.93332354
#   5.52460697 4.86587379 4.18184486 4.60581366 5.32560184 4.49741481
#   3.92966871 4.33759902 4.65366925 5.22721044 3.94875991 5.39507307
#   4.86293686]
#  [6.61990413 6.31418111 6.36703478 6.73837701 6.44708384 5.75082949
#   5.26228315 5.58340538 6.43849239 5.25997336 5.17078685 5.8812906
#   6.2354632  5.34368976 5.7792576  5.17198184 5.60630971 5.28886715
#   4.59102497 5.14685614 5.02107582 4.85248931 4.87905599 5.99313988
#   6.44748958]
#  [5.34020908 5.48588307 5.38522535 5.80293809 5.52011377 5.17515492
#   5.16076389 4.33832486 5.14288327 5.4942894  5.23090766 4.63107508
#   5.48024986 4.31490773 4.86721189 4.00424499 5.24496627 5.17220885
#   3.63675164 4.44378198 5.16222241 5.24345207 5.0636027  5.09417498
#   5.12560786]
#  [5.08113028 5.44982141 5.77729371 5.54978932 5.3983804  4.90326812
#   4.33228736 4.58230538 4.55775209 4.36506757 4.4875975  4.28297529
#   5.37387095 4.21046849 4.66965347 4.14682941 4.53934606 4.24568706
#   4.13479306 4.29054894 4.77556092 5.03960681 3.79445438 5.11973604
#   4.54608433]
#  [4.93047135 4.63817268 4.42528242 5.53214029 4.79585603 4.60477125
#   4.71672625 5.14533448 5.00023287 4.6843069  5.01196367 4.17340072
#   4.8326434  4.64648795 4.24979953 3.79010733 5.07175209 4.48928143
#   3.05931045 4.20761285 4.6772885  4.3973863  4.15312377 4.75184931
#   5.08848158]
#  [5.777628   6.32072774 5.54930136 7.08577581 5.99715475 4.82011017
#   5.9977393  5.61126414 5.39261968 4.63422955 5.325897   4.91287919
#   5.16372265 5.69689944 5.10423792 4.23410387 6.42590404 4.85284782
#   3.9946337  5.59419459 5.18251165 5.21052853 4.75441502 5.43963567
#   5.39281939]
#  [5.62400892 5.46416466 5.51199264 6.55159352 5.89249615 5.19851418
#   5.55558204 5.26537841 5.54810811 4.95070981 5.47653695 5.75371778
#   6.10019849 6.32962793 4.91457612 3.66568551 6.09063802 5.94587703
#   4.24913617 5.6350295  5.17104058 5.94370582 4.7753803  6.32654424
#   6.00967005]]
# 1227.588313037537

# %%
array2=np.random.random(size=(10,1))
print(array2)
print("*"*80)
array3=np.ndarray((10,1))
def func(x):
    return 1/1+ np.exp(-x)
List=list()
List1=list()
for i in range(0,array2.shape[0]):
    List.clear()
    for j in array2[i]:
        List.append(func(j))
    List1.append(List)
print(List1)
np.array(List1)
# Out:
# [[0.85303791]
#  [0.06356593]
#  [0.69515187]
#  [0.32127915]
#  [0.70402724]
#  [0.97909988]
#  [0.79796528]
#  [0.86853064]
#  [0.20132552]
#  [0.2503144 ]]
# ********************************************************************************
# [[1.7785559703205487], [1.7785559703205487], [1.7785559703205487], [1.7785559703205487], [1.7785559703205487], [1.7785559703205487], [1.7785559703205487], [1.7785559703205487], [1.7785559703205487], [1.7785559703205487]]
# array([[1.77855597],
#        [1.77855597],
#        [1.77855597],
#        [1.77855597],
#        [1.77855597],
#        [1.77855597],
#        [1.77855597],
#        [1.77855597],
#        [1.77855597],
#        [1.77855597]])
